% %% [markdown]
% # Время жизни нейтрона
%
% Нейтрон  &mdash; тяжёлая элементарная частица, не имеющая электрического заряда. Нейтроны и протоны являются двумя главными компонентами атомных ядер; общее название для протонов и нейтронов &mdash; нуклоны.
%
% ![Neutron_quark_structure.png](attachment:Neutron_quark_structure.png)
%
% <center>Рис. 1. Кварковая структура нейтрона</center>
%
% Считается надёжно установленным, что нейтрон является связанным состоянием трёх кварков: одного "верхнего" (*u*) и двух "нижних" (*d*) кварков (кварковая структура *udd*). Близость значений масс протона и нейтрона обусловлена свойством приближённой изотопической инвариантности: в протоне (кварковая структура *uud*) один *d*-кварк заменяется на *u*-кварк, но поскольку массы этих кварков очень близки, такая замена слабо сказывается на массе составной частицы.
% Про кварковую модель и трудности измерения массы одного из кварков можно прочитать в блокноте [Масса *t*-кварка](TopQuark.ipynb).

% %% [markdown]
% Поскольку нейтрон тяжелее протона (на 0.001 388 449 33(49) а.е.м.), то он может распадаться в свободном состоянии.
% Бета-распад нейтрона &mdash; спонтанное превращение свободного нейтрона в протон с излучением $\beta$-частицы (электрона) и электронного антинейтрино:
%
% $$
% n \rightarrow p + e^{-}+ \overline{\nu}_{e}.
% $$
%
% Диаграмма Фейнмана для бета-распада нейтрона на протон, электрон и электронное антинейтрино при участии виртуального тяжёлого $W^{-}$-бозона приведена на рисунке 2.
%
% ![Beta_Negative_Decay.png](attachment:Beta_Negative_Decay.png)
%
% <center>Рис. 2. Бета-распад нейтрона</center>
%
% На рисунке 2 вертикальной стрелкой показано направление хода времени. У основания стрелки представлено обозначение начальной частицы &mdash; нейтрона и его кварковой структуры. В верхней части диаграммы &mdash; конечные продукты реакции. Горизонтальной волнистой линией обозначена виртуальная частица &mdash; $W^{-}$-бозон, которая не регистрируется экспериментально.

% %% [markdown]
% Популярное описание истории измерений времени жизни нейтрона содержатся в публикации [[2]](#elementy2013) 2013 года.
%
% Организация [Particle Data Group (PDG)](https://pdg.lbl.gov/2020/html/about\_pdg.html) &mdash; международная коллаборация, которая занимается сверкой и представлением данных о физике частиц  и публикует обзоры *Review of Particle Physics*. В отчете 2012 года [[1]](#PDG2012) приводится интересная иллюстрация.
%
%
% ![TnResults2012.png](attachment:TnResults2012.png)
%
% <center>Рис. 3. Время жизни нейтрона &mdash; история измерений до 2013 года</center>
%
% По графику можно судить о том, как изменялись со временем как точность измерений, так значение времени жизни нейтрона.
%
% В публикации 2019 года [[3]](#UFN2019) приводятся ссылки на результаты последних лет.
%
% <center><br>Таблица 1. Сводка результатов экспериментов по измерению времени жизни нейтрона (c).</center>.
%
% | Среднее $\pm$ стат. погрешность $\pm$ сист. погрешность |  Ссылка  |
% | :------- | :--------: |
% | 918 $\pm$ 14               | [[4]](#Christensen1972)   |
% | 903 $\pm$ 13               | [[5]](#Morozov1986)       |
% | 891 $\pm$ 9                | [[6]](#Spivak1988)        |
% | 881.1 $\pm$ 3.1 $\pm$ 1.1  | [[7]](#Nesvizhevskii1992) |
% | 887.4 $\pm$ 1.7            | [[8]](#Schreckenbach1992) |
% | 881.0 $\pm$ 3.0            | [[9]](#MAMBOII2000)       |
% | 880.7 $\pm$ 1.3 $\pm$ 1.2  | [[10]](#Pichlmaier2010)   |
% | 882.5 $\pm$ 2.1            | [[11]](#Steyerl2012)      |
% | 881.6 $\pm$ 0.8 $\pm$ 1.9  | [[12]](#Morozov2012)      |
% | 880.2 $\pm$ 1.2            | [[13]](#Morozov2015)      |
% | 881.5 $\pm$ 0.7 $\pm$ 0.6  | [[14]](#Serebrov2017)     |
% | 878.3  $\pm$ 1.6 $\pm$ 1.0 | [[15]](#Ezhov2018)        |
% | 877.7  $\pm$ 0.7 $\pm$ 0.4 | [[16]](#Pattie2018)       |
%
% Большинство измерений, приведенных в таблице, использует технику хранения ультрахолодных нейтронов в замкнутом объёме. Два последних результата выполнено с использованием магнито-гравитационной ловушки.

% %% [markdown]
% В последние годы активно обсуждается вопрос о возможности недоучёта систематических погрешностей в "ловушечных" экспериментах и необходимости новых экспериментов без взаимодействия нейтронов с поверхностями.
%
% ![TnDiscrepancy2018.png](attachment:TnDiscrepancy2018.png)
%
% На предыдущем рисунке приводится график из публикации 2018 года [[17]](#Wietfeldt2018) с критическим анализом вопроса и обширной библиографией. Серым цветом выделены два коридора данных по времени жизни нейтрона: по времяпролетных экспериментов &mdash; в верхней части рисунка, и по хранению нейтронов &mdash; внизу. Отмечается значимое и устойчивое расхождение между данными разных типов.
%
% $$
% T_n = \left\lbrace \begin{matrix}
% 888.1 \pm 2.0 \text{ s} & \text{ --- на пучках}, \\
% 879.45 \pm 0.58 \text{ s} & \text{ --- в ловушках}.
% \end{matrix}\right.
% $$
%
% Разница составляет
% $$
% 8.7 \pm 2.1 \text{ s} \ (4\sigma)
% $$
%
% Таким образом, существует значимое расхождение результатов, полученных с использованием разных методик, требующее критического анализа и дальнейших исследований.

% %% [markdown]
% ## Cписок литературы
%
% 1. <a id='PDG2012'></a> Particle Data Group report 2012.
% https://pdg.lbl.gov/2013/reviews/rpp2012-rev-history-plots.pdf
%
% 2. <a id='elementy2013'></a>
% И. Иванов. *Измерения времени жизни нейтрона, выполненные разными методами, по-прежнему расходятся (03.12.2013).*
% https://elementy.ru/novosti_nauki/432146
%
% 3. <a id='UFN2019'></a>
% А.П. Серебров. *Разногласие между методом хранения ультрахолодных нейтронов и пучковым методом при измерении времени жизни нейтрона.* // УФН 189 635–641 (2019).
% DOI: [10.3367/UFNr.2018.11.038475](http://doi.org/10.3367/UFNr.2018.11.038475)
%
% 4. <a id='Christensen1972'></a>
% C. J. Christensen, A. Nielsen, A. Bahnsen, W. K. Brown, and B. M. Rustad. *Free-Neutron Beta-Decay Half-Life* // Phys. Rev. D 5 1628 (1972)
% DOI: [10.1103/PhysRevD.5.1628](http://doi.org/10.1103/PhysRevD.5.1628)
%
% 5. <a id='Morozov1986'></a>
% Kosvintsev Yu. Yu, Morozov V. I., Terekhov G.I. // JETP Lett. 44 571 (1986)
% http://jetpletters.ac.ru/ps/1397/article_21182.pdf
%
% 6. <a id='Spivak1988'></a>
% Spivak P.E. // Sov. Phys. JETP 67 1735 (1988)
% http://www.jetp.ac.ru/cgi-bin/dn/e_067_09_1735.pdf
%
% 7. <a id='Nesvizhevskii1992'></a>
% V. V Nesvizhevskii, A. P. Serebrov, R. R. Tal'daev, and A. G. Kharitonov, V. P. Alfimenkov, A. V. Strelkov, and V. N. Shvetsov. *Measurement of the neutron lifetime in a gravitational trap and analysis of experimental errors.* // JETP, 1992, Vol. 75, No. 3, p. 405.
% http://jetp.ac.ru/cgi-bin/dn/e_075_03_0405.pdf
%
% 8. <a id='Schreckenbach1992'></a>
% K. Schreckenbach (Laue-Langevin Inst.), W. Mampe (Laue-Langevin Inst.) *The Lifetime of the free neutron* // J.Phys.G 18 (1992) 1-34
% DOI: [10.1088/0954-3899/18/1/004](http://doi.org/10.1088/0954-3899/18/1/004)
%
% 9. <a id='MAMBOII2000'></a>
% A. Pichlmaier, J. Butterworth, P. Geltenbort, H. Nagel, V. Nesvizhevsky, K. Schreckenbach, E. Steichele, S. Neumaier, V. Varlamov. *MAMBO II: Neutron lifetime measurement with storage of ultra-cold neutrons* // Nucl.Instrum.Meth.A 440 (2000) 517-521
% DOI: [10.1016/S0168-9002(99)01029-3](http://doi.org/10.1016/S0168-9002(99)01029-3)
%
% 10. <a id='Pichlmaier2010'></a>
% A.Pichlmaier, V.Varlamov, K.Schreckenbach, P.Geltenbort. *Neutron lifetime measurement with the UCN trap-in-trap* // MAMBO II Physics Letters B Volume 693, Issue 3, 4 October 2010, 221-226
% DOI: [10.1016/j.physletb.2010.08.032](http://doi.org/10.1016/j.physletb.2010.08.032)
%
% 11. <a id='Steyerl2012'></a>
% A. Steyerl, J. M. Pendlebury, C. Kaufman, S. S. Malik, and A. M. Desai *Quasielastic scattering in the interaction of ultracold neutrons with a liquid wall and application in a reanalysis of the Mambo I neutron-lifetime experiment* // Phys. Rev. C 85, 065503 June 2012
% DOI: [10.1103/PhysRevC.85.065503](http://doi.org/10.1103/PhysRevC.85.065503)
%
% 12. <a id='Morozov2012'></a>
% Arzumanov, S.S., Bondarenko, L.N., Morozov, V.I. et al. *Analysis and correction of the measurement of the neutron lifetime.* // JETP Lett. 95, 224–228 (2012).
% DOI: [10.1134/S0021364012050025](http://doi.org/10.1134/S0021364012050025)
%
% 13. <a id='Morozov2015'></a>
% S. Arzumanov, L. Bondarenko, S. Chernyavsky, P. Geltenbort, V. Morozov, V.V. Nesvizhevsky, Yu. Panin, A. Strepetov *A measurement of the neutron lifetime using the method of storage of ultracold neutrons and detection of  inelastically up-scattered neutrons* // Phys.Lett.B 745 (2015) 79-89
% DOI: [10.1016/j.physletb.2015.04.021](http://doi.org/10.1016/j.physletb.2015.04.021)
%
% 14. <a id='Serebrov2017'></a>
% Serebrov, A.P., Kolomenskiy, E.A., Fomin, A.K. et al. *New measurement of the neutron lifetime with a large gravitational trap* // JETP Lett. 106, 623–629 (2017).
% DOI: [10.1134/S0021364017220143](http://doi.org/10.1134/S0021364017220143)
%
% 15. <a id='Ezhov2018'></a>
% Ezhov, V.F., Andreev, A.Z., Ban, G. et al. *Measurement of the Neutron Lifetime with Ultracold Neutrons Stored in a Magneto-Gravitational Trap* // JETP Lett. 107, 671–675 (2018).
% DOI: [10.1134/S0021364018110024](http://doi.org/10.1134/S0021364018110024)
%
% 16. <a id='Pattie2018'></a>
% R. W. Pattie Jr., N. B. Callahan, C. Cude-Woods et all. *Measurement of the neutron lifetime using a magneto-gravitational trap and in situ detection* // Science  11 May 2018: Vol. 360, Issue 6389, pp. 627-632
% DOI: [10.1126/science.aan8895](http://doi.org/10.1126/science.aan8895)
%
% 17. <a id='Wietfeldt2018'></a>
% F.E. Wietfeldt. Measurements of the Neutron Lifetime. *Atoms* 2018, 6(4), 70.
% DOI: [10.3390/atoms6040070](http://doi.org/10.3390/atoms6040070)
%
% 18. <a id='Oskorbin1998'></a>
% Оскорбин Н.М., Максимов А.В., Жилин С.И. *Построение и анализ эмпирических зависимостей методом центра неопределенности* // Известия Алтайского государственного университета 1 (5), 1998, С. 37-40.
% http://izvestia.asu.ru/1998/1/info/TheNewsOfASU-1998-1-info-01.pdf

% %%
# Загрузка пакета для интервальных вычислений
pkg load interval

% %%
# Загрузить данные 
load data/neutron.mat

data = neutron.data;
data_vars = neutron.vars

neutron_mid = data(:,1); 
neutron_rad_std = data(:,2); 
neutron_rad_std_syst = data(:,2) + data(:,4); 

# Интервальные измерения только со случайной погрешностью
NTstd = midrad(neutron_mid, neutron_rad_std)

# Интервальные измерения со случайной и систематической погрешностью
NTtotal = midrad(neutron_mid, neutron_rad_std_syst)
% Out:
% data_vars =
% {
%   [1,1] = mean_val
%   [2,1] = eps_minus
%   [3,1] = eps_plus
%   [4,1] = systematic_eps_minus
%   [5,1] = systematic_eps_plus
% }
%
% NTstd ⊂ 9×1 interval vector
%
%    [877.79, 879.21]_com
%     [876.69, 879.9]_com
%    [879.39, 882.01]_com
%    [880.79, 882.41]_com
%    [881.09, 883.91]_com
%     [886.5, 888.91]_com
%       [879, 881.41]_com
%       [877, 878.41]_com
%    [880.79, 882.21]_com
%
% NTtotal ⊂ 9×1 interval vector
%
%      [877.5, 879.5]_com
%     [875.69, 880.9]_com
%     [878.2, 883.21]_com
%    [878.89, 884.31]_com
%    [879.59, 885.41]_com
%     [884.6, 890.81]_com
%       [879, 881.41]_com
%     [876.7, 878.71]_com
%    [880.19, 882.81]_com

% %%
# Графическое представление интервальных данных
nums = 1:numel(NTtotal);
vals = mid(NTtotal);
errorbar (vals, nums, rad(NTtotal), rad(NTtotal),">.r");
ylim([0 nums(end)+1])
hold on
h = errorbar (vals, nums, rad(NTstd), rad(NTstd),">.b");
set(h,"linewidth",6)
set(h,"markersize",12)
title ("Interval measurements of neutron life time");
xlabel("Neutron life time, s")
ylabel("Measurement number")
legend ("Measurements with total errors","Measurements with std errors","location","southeast");
#grid on

% %%
# Пересечение интервалов пусто, т.е. интервальная выборка несовместна
intersect(NTtotal)
% Out:
% ans = [Empty]_trv

% %%
# Функция построения оценки константы по интервальным измерениям 
# методом центра неопределённости (МЦН) [18]
function [oskorbin_center, k] = estimate_uncertainty_center(intervals)
  n = numel(intervals);
  y = mid(intervals);
  e = rad(intervals);
  A = [ones(n,1), -e; -ones(n,1), -e];
  b = [y; -y];  
  c = [0 1];
  lb = [-Inf 0];
  ub = [Inf Inf];  
  ctype(1:2*n) = 'U'; 
  vartype(1:2) = 'C';
  sense = 1;
  [beta, fval, exitcode] = glpk (c, A, b, lb, ub, ctype, vartype, sense);
  if exitcode < 0
      return
  end   
  oskorbin_center = beta(1);
  k = beta(2);
end

% %%
# МЦН-оценка времени жизни нейрона и минимальный коэффициент расширения интервалов для совместности выборки
[oskorbin_center, k] = estimate_uncertainty_center(NTtotal)
% Out:
% oskorbin_center =  880.14
% k =  2.4390

% %%
# Графическое представление интервальных данных и МЦН-оценки значения времени жизни нейтрона
errorbar (vals, nums, k*rad(NTtotal), k*rad(NTtotal),">.k");
ylim([0 nums(end)+1])
hold on
h = errorbar (vals, nums, rad(NTtotal), rad(NTtotal),">.r");
set(h,"linewidth",4)
h = errorbar (vals, nums, rad(NTstd), rad(NTstd),">.b");
set(h,"linewidth",6)
set(h,"markersize",12)
title ("Interval measurements of neutron lifetime");
xlabel("Neutron life time, s")
ylabel("Measurement number")
plot(oskorbin_center*[1 1], ylim, 'm--')
legend ("k-scaled measurements", "Measurements with total errors",...
        "Measurements with standard errors", "Oskorbin center",...
        "location","southeast");
